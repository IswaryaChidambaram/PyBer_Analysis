# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis,label='Boston')

# %%
fig,ax=plt.subplots()
ax.plot(x_axis,y_axis)

# %%
ax=plt.axes()
ax.plot(x_axis,y_axis,label='Boston', marker="*", color="green", linewidth=2)
ax.set_xlabel('date')
ax.set_ylabel('fare ($)')
ax.set_title("Pyber Fare by Month")
ax.grid()
ax.set_ylim(0,45)
ax.legend()

# %%
plt.plot(x_axis,y_axis,'o',label='Chicago', marker="*", color="red", linewidth=2)
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.xlim(0,45)
plt.title('Pyber Fare by Month')
plt.gca().invert_xaxis()
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis,y_axis,label="Boston",color="green")
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("")
plt.legend()

# %%
plt.barh(x_axis,y_axis,label="Boston",color="magenta")
plt.title("PyBer Fares by Month")
plt.xlabel("Fare($)")
plt.ylabel("Month")
plt.gca().invert_yaxis()
plt.legend()

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=[i* 5 for i in y_axis])
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis,explode=explode_values,colors=colors,autopct='%.1f%%')
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.subplots(figsize=(8, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4f9060de1584> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.pie(y_axis,labels=x_axis,explode=explode_values,colors=colors,autopct='%.1f%%')
#       3 explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
#       4 ax.subplots(figsize=(8, 8))
#       5 plt.show()
#
# NameError: name 'explode_values' is not defined
